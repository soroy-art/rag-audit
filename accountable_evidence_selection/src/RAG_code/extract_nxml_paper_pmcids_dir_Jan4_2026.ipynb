# %%
from pathlib import Path
import shutil

# %%
def extract_nxml_from_pmc_folders(pkg_dir, dest_nxml_dir, overwrite=False):
    """
    For each immediate subfolder of pkg_dir (expected: one per PMCID),
    find .nxml recursively, pick the largest if multiple, and copy it to:

        <PMCID_folder>/<immediate_parent_folder_of_nxml>.nxml
    """
    pkg_dir = Path(pkg_dir)
    dest_nxml_dir = Path(dest_nxml_dir)
    rows = []

    for pmc_dir in sorted([p for p in pkg_dir.iterdir() if p.is_dir()]):
        pmcid = pmc_dir.name

        nxmls = [p for p in pmc_dir.rglob("*.nxml") if p.is_file()]
        if not nxmls:
            rows.append({"pmcid_dir": pmcid, "found_nxml": None, "copied_to": None, "status": "no_nxml"})
            continue

        # If multiple .nxml files exist, take the largest (often the main article)
        nxml = max(nxmls, key=lambda p: p.stat().st_size)

        immediate_folder = nxml.parent.name
        dest = dest_nxml_dir / f"{immediate_folder}.nxml"

        if dest.exists() and not overwrite:
            rows.append({"pmcid_dir": pmcid, "found_nxml": str(nxml), "copied_to": str(dest), "status": "exists_skip"})
            continue

        try:
            shutil.copy2(nxml, dest)  # preserves timestamps/metadata
            rows.append({"pmcid_dir": pmcid, "found_nxml": str(nxml), "copied_to": str(dest), "status": "copied"})
        except Exception as e:
            rows.append({"pmcid_dir": pmcid, "found_nxml": str(nxml), "copied_to": None, "status": f"copy_failed: {e}"})

    return rows

# %%
pkg_dir = Path("../results/pmc_openaccess_xml_periop_care") / "oa_packages"
dest_nxml_dir = Path("../results/pmc_openaccess_xml_periop_care") / "nxml_files"
results = extract_nxml_from_pmc_folders(pkg_dir, dest_nxml_dir, overwrite=False)

# Print results (or convert to pandas DataFrame if you prefer)
for r in results:
    print(r)
# Out:
# {'pmcid_dir': 'PMC10520188', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC10520188/PMC10520188/68_2023_Article_2271.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC10520188.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11072254', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11072254/PMC11072254/0102-6720-abcd-37-e1794.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11072254.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11161250', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11161250/PMC11161250/sla-280-056.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11161250.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11222175', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11222175/PMC11222175/101_2024_Article_1424.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11222175.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11224558', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11224558/PMC11224558/ejanet-41-618.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11224558.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11282474', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11282474/PMC11282474/main.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11282474.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11289045', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11289045/PMC11289045/464_2024_Article_10977.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11289045.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11427556', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11427556/PMC11427556/10877_2024_Article_1132.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11427556.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11455680', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11455680/PMC11455680/13304_2024_Article_1860.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11455680.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11666733', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11666733/PMC11666733/464_2024_Article_11433.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11666733.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11744056', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11744056/PMC11744056/JOCD-24-e16712.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11744056.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11885194', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11885194/PMC11885194/ANAE-80-412.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11885194.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC11885198', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC11885198/PMC11885198/ANAE-80-425.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC11885198.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12146249', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12146249/PMC12146249/IJU-32-621.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12146249.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12240022', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12240022/PMC12240022/IMJ-55-1174.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12240022.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12338406', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12338406/PMC12338406/WJS-49-2055.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12338406.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12338446', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12338446/PMC12338446/WJS-49-1997.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12338446.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12338449', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12338449/PMC12338449/WJS-49-2029.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12338449.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12420935', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12420935/PMC12420935/10.1177_0310057X251355288.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12420935.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12574511', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12574511/PMC12574511/cm9-138-2702.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12574511.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12687548', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12687548/PMC12687548/12902_2025_Article_2013.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12687548.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC12750329', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC12750329/PMC12750329/znaf272.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC12750329.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC3872300', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC3872300/PMC3872300/464_2013_Article_3170.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC3872300.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC4956681', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC4956681/PMC4956681/ane-123-452.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC4956681.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC5029585', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC5029585/PMC5029585/ANAE-70-859.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC5029585.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC5100245', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC5100245/PMC5100245/ACA-19-73.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC5100245.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC5323492', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC5323492/PMC5323492/134_2016_Article_4665.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC5323492.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC5540357', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC5540357/PMC5540357/tp-101-s7.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC5540357.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC5629911', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC5629911/PMC5629911/abc-109-03-s1-0001.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC5629911.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC6135479', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC6135479/PMC6135479/ane-127-0967.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC6135479.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC6313353', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC6313353/PMC6313353/268_2018_Article_4753.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC6313353.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC6510875', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC6510875/PMC6510875/10388_2018_Article_642.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC6510875.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC6681143', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC6681143/PMC6681143/ANAE-70-623.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC6681143.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC7274637', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC7274637/PMC7274637/main.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC7274637.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC7983964', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC7983964/PMC7983964/13017_2021_Article_349.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC7983964.nxml', 'status': 'copied'}
# {'pmcid_dir': 'PMC8250763', 'found_nxml': '../results/pmc_openaccess_xml_periop_care/oa_packages/PMC8250763/PMC8250763/ANAE-76-940.nxml', 'copied_to': '../results/pmc_openaccess_xml_periop_care/nxml_files/PMC8250763.nxml', 'status': 'copied'}
